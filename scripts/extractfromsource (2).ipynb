# %%
# !pip3 install azure-storage-blob # Microoft Azure

# %%
# Import libraries
from io import StringIO
import numpy as np
import pandas as pd
import json
import requests
from google.colab import files
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient

# %% [markdown]
# Uploading the 2022 ownership payment data

# %%
#Extracting from datasource
df_raw = pd.read_csv("/content/OP_DTL_OWNRSHP_PGYR2022_P01182024.csv")

print(df_raw.info)
print(df_raw.shape)
df_raw.head()
# Out:
# <bound method DataFrame.info of      Change_Type  Physician_Profile_ID  Physician_NPI Physician_First_Name  \
# 0      UNCHANGED                835160   1.588622e+09            ELIZABETH
# 1      UNCHANGED                 40572   1.891791e+09                 Eric
# 2      UNCHANGED               1175626   1.538509e+09                DAVID
# 3      UNCHANGED                229524   1.073615e+09                  JED
# 4      UNCHANGED                276414   1.104889e+09               Andrew
# ...          ...                   ...            ...                  ...
# 3911   UNCHANGED                 91748   1.013948e+09              Pauline
# 3912   UNCHANGED                234310   1.164416e+09                 Pete
# 3913   UNCHANGED                210308   1.649379e+09                 Phan
# 3914   UNCHANGED                980087   1.659358e+09             Phelicia
# 3915   UNCHANGED                276581   1.104903e+09               Philip
#
# ...

# %%
#Specify the path to your JSON configuration file
config_file_path= 'config.json'

#Load the JSON configuration file
with open (config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = '2022paymentdata'
blob_name = "/content/OP_DTL_OWNRSHP_PGYR2022_P01182024.csv"

#Convert Dataframe to CSV
output = StringIO()
df_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

#Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

#Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Upload {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}")
# Out:
# Upload /content/OP_DTL_OWNRSHP_PGYR2022_P01182024.csv to Azure Blob Storage in container 2022paymentdata

# %% [markdown]
# Uploading the 2022 research payment data

# %%
# Extracting from datasource
df_raw_rsrch = pd.read_csv("/content/OP_DTL_RSRCH_PGYR2022_P01182024.csv")

print(df_raw_rsrch.info())  # Note the parentheses after info
print(df_raw_rsrch.shape)
print(df_raw_rsrch.head())

# %%
#Specify the path to your JSON configuration file
config_file_path= 'config.json'

#Load the JSON configuration file
with open (config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = '2022paymentdata'
blob_name = "/content/OP_DTL_RSRCH_PGYR2022_P01182024.csv"

#Convert Dataframe to CSV
output = StringIO()
df_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

#Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

#Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Upload {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}")
# Out:
# Upload /content/OP_DTL_RSRCH_PGYR2022_P01182024.csv to Azure Blob Storage in container 2022paymentdata

# %% [markdown]
# Uploading the 2022 general payment data

# %%
#Specify the path to your JSON configuration file
config_file_path= 'config.json'

#Load the JSON configuration file
with open (config_file_path, 'r') as config_file:
  config = json.load(config_file)

CONNECTION_STRING_AZURE_STORAGE = config["connectionString"]
CONTAINER_AZURE = '2022paymentdata'
blob_name = "/content/drive/MyDrive/OP_DTL_GNRL_PGYR2022_P01182024.csv"

#Convert Dataframe to CSV
output = StringIO()
df_raw.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

#Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

#Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Upload {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}")
# Out:
# Upload /content/drive/MyDrive/OP_DTL_GNRL_PGYR2022_P01182024.csv to Azure Blob Storage in container 2022paymentdata

# %%
# Extracting from datasource
df_raw_rsrch = pd.read_csv("/content/drive/MyDrive/OP_DTL_GNRL_PGYR2022_P01182024.csv")

print(df_raw_rsrch.info())  # Note the parentheses after info
print(df_raw_rsrch.shape)
print(df_raw_rsrch.head())

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
